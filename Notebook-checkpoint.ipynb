# %% [markdown]
# ## import some relevant libaries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import warnings
import json
import random
import string
import os
# %matplotlib inline
sns.set()

# %% [markdown]
# ## read out the necessary files

# %%
samplesubmission=pd.read_csv('Updated_Sample_Submission.csv')
train=pd.read_csv('Update_train.csv')
test=pd.read_csv('Updated_Test.csv')
train_trimmed=pd.read_csv('Train_trimmed.csv')
test_trimmed=pd.read_csv('Updated_Test_trimmed.csv')

# %%
train.head()
# Out:
#    absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# 0     0.520883     0.528200     0.529795     0.537382     0.540265
# 1     0.529109     0.534852     0.541075     0.544269     0.546594
# 2     0.528434     0.532036     0.540413     0.541964     0.549347
# 3     0.530528     0.531880     0.539558     0.542433     0.549097
# 4     0.527530     0.536424     0.538207     0.541504     0.550546
#
#    absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# 0     0.546260     0.550882     0.558865     0.571352     0.585775  ...
# 1     0.555183     0.561367     0.567637     0.582427     0.595801  ...
# 2     0.555902     0.561458     0.567824     0.579568     0.593048  ...
# 3     0.556224     0.561398     0.566963     0.577525     0.591982  ...
# 4     0.555203     0.560394     0.567352     0.579438     0.592049  ...
#
#    absorbance168  absorbance169  id     std  temperature  humidity  \
# 0       1.319344       1.278294   0  0.0026        39.27     44.17
# 1       1.282723       1.267465   1  0.0026        39.39     44.09
# 2       1.287730       1.266464   2  0.0026        39.50     44.00
# 3       1.314408       1.342224   3  0.0026        39.60     43.89
# 4       1.268710       1.216146   4  0.0026        39.70     43.83
#
#    hdl_cholesterol_human  hemoglobin(hgb)_human  cholesterol_ldl_human  \
# 0                    low                     ok                   high
# 1                    low                     ok                   high
# 2                    low                     ok                   high
# 3                    low                     ok                   high
# 4                    low                     ok                   high
#
#    donation_id
# 0         2250
# 1         2250
# 2         2250
# 3         2250
# 4         2250
#
# [5 rows x 178 columns]

# %% [markdown]
# ## checking out the data given

# %%
samplesubmission.head()
# Out:
#                      Donation_ID target
# 0  ID_1961_cholesterol_ldl_human     ok
# 1  ID_1961_hdl_cholesterol_human     ok
# 2  ID_1961_hemoglobin(hgb)_human     ok
# 3  ID_2067_cholesterol_ldl_human     ok
# 4  ID_2067_hdl_cholesterol_human     ok

# %%
samplesubmission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Donation_ID  183 non-null    object
#  1   target       183 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %%
samplesubmission.describe()
# Out:
#                           Donation_ID target
# count                             183    183
# unique                            183      1
# top     ID_3688_cholesterol_ldl_human     ok
# freq                                1    183

# %%
train.columns
# Out:
# Index(['absorbance0', 'absorbance1', 'absorbance2', 'absorbance3',
#        'absorbance4', 'absorbance5', 'absorbance6', 'absorbance7',
#        'absorbance8', 'absorbance9',
#        ...
#        'absorbance168', 'absorbance169', 'id', 'std', 'temperature',
#        'humidity', 'hdl_cholesterol_human', 'hemoglobin(hgb)_human',
#        'cholesterol_ldl_human', 'donation_id'],
#       dtype='object', length=178)

# %%
train.describe()
# Out:
#         absorbance0   absorbance1   absorbance2   absorbance3   absorbance4  \
# count  29160.000000  29160.000000  29160.000000  29160.000000  29160.000000
# mean       0.501233      0.505343      0.509430      0.513951      0.520390
# std        0.154276      0.114408      0.108543      0.131905      0.130735
# min       -2.793790     -1.875939     -1.733555     -2.270881     -2.239499
# 25%        0.486140      0.488110      0.491822      0.496990      0.502719
# 50%        0.509431      0.511737      0.515532      0.521206      0.527353
# 75%        0.530501      0.532439      0.536944      0.542858      0.549445
# max        0.657782      0.652291      0.659153      0.658982      0.659410
#
#         absorbance5   absorbance6   absorbance7   absorbance8   absorbance9  \
# count  29160.000000  29160.000000  29160.000000  29160.000000  29160.000000
# mean       0.527901      0.534790      0.539878      0.547992      0.560161
# std        0.127874      0.115413      0.122235      0.120122      0.121974
# min       -2.172958     -1.870428     -2.021362     -1.963416     -1.990968
# 25%        0.509847      0.516403      0.522104      0.530236      0.542101
# 50%        0.534120      0.540330      0.546182      0.554205      0.567028
# 75%        0.556553      0.563126      0.568506      0.576613      0.589161
# max        0.667296      0.672708      0.680601      0.691116      0.704255
#
#        ...  absorbance165  absorbance166  absorbance167  absorbance168  \
# count  ...   29160.000000   29160.000000   29160.000000   29160.000000
# mean   ...       1.256808       1.250286       1.247337       1.261093
# std    ...       0.147095       0.157714       0.165125       0.172043
# min    ...      -1.399953      -1.618211      -1.746980      -1.840234
# 25%    ...       1.209375       1.198047       1.191282       1.200460
# 50%    ...       1.259995       1.253789       1.251885       1.264090
# 75%    ...       1.313490       1.312229       1.311609       1.328095
# max    ...       1.606844       1.586301       1.657884       1.672314
#
#        absorbance169            id           std   temperature      humidity  \
# count   29160.000000  29160.000000  29160.000000  29160.000000  29160.000000
# mean        1.249279  18395.467078      0.007525     41.243166     35.340352
# std         0.142374  11516.122819      0.004625      2.833117      8.700879
# min        -0.995391      0.000000      0.002400     30.480000     16.610000
# 25%         1.187413   7289.750000      0.004500     39.180000     28.300000
# 50%         1.250164  21499.500000      0.006100     41.200000     35.295000
# 75%         1.314102  28789.250000      0.008900     43.130000     41.190000
# max         1.738621  36079.000000      0.028700     52.690000     67.820000
#
#         donation_id
# count  29160.000000
# mean    6647.707819
# std     3036.003039
# min     1975.000000
# 25%     3593.000000
# 50%     6428.500000
# 75%     9326.000000
# max    11906.000000
#
# [8 rows x 175 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29160 entries, 0 to 29159
# Columns: 178 entries, absorbance0 to donation_id
# dtypes: float64(173), int64(2), object(3)
# memory usage: 39.6+ MB

# %%
test.columns
# Out:
# Index(['Reading_ID', 'donation_id', 'absorbance0', 'absorbance1',
#        'absorbance2', 'absorbance3', 'absorbance4', 'absorbance5',
#        'absorbance6', 'absorbance7',
#        ...
#        'absorbance164', 'absorbance165', 'absorbance166', 'absorbance167',
#        'absorbance168', 'absorbance169', 'id', 'std', 'temperature',
#        'humidity'],
#       dtype='object', length=176)

# %%
test.head()
# Out:
#     Reading_ID donation_id  absorbance0  absorbance1  absorbance2  \
# 0  ID_KWUAQLRM     ID_2982     0.517951     0.520508     0.526852
# 1  ID_FN8SIVJJ     ID_2982     0.517839     0.522367     0.525186
# 2  ID_CI4TQCHI     ID_2982     0.517702     0.522018     0.527237
# 3  ID_URJMKNU7     ID_2982     0.525008     0.527439     0.536871
# 4  ID_HBJH67IS     ID_2982     0.520532     0.522683     0.526842
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.531611     0.536816     0.543828     0.547761     0.554379  ...
# 1     0.534661     0.541900     0.546180     0.551687     0.556753  ...
# 2     0.534374     0.541155     0.547152     0.549837     0.557513  ...
# 3     0.539636     0.546555     0.553183     0.558826     0.563549  ...
# 4     0.534634     0.539676     0.547488     0.552688     0.558355  ...
#
#    absorbance164  absorbance165  absorbance166  absorbance167  absorbance168  \
# 0       1.226695       1.210430       1.214422       1.200332       1.198297
# 1       1.219627       1.216220       1.191416       1.202515       1.211942
# 2       1.237193       1.208477       1.208721       1.187810       1.209599
# 3       1.218532       1.185708       1.196750       1.222484       1.177406
# 4       1.206383       1.204950       1.203311       1.191351       1.157577
#
#    absorbance169  id     std  temperature  humidity
# 0       1.248182   0  0.0027        37.09     27.22
# 1       1.242939   1  0.0027        37.20     27.17
# 2       1.175631   2  0.0027        37.30     27.07
# 3       1.198399   3  0.0027        37.38     26.98
# 4       1.212008   4  0.0027        37.48     26.89
#
# [5 rows x 176 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Columns: 176 entries, Reading_ID to humidity
# dtypes: float64(173), int64(1), object(2)
# memory usage: 4.9+ MB

# %%
test.describe()
# Out:
#        absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000
# mean      0.508946     0.511336     0.515381     0.520707     0.527094
# std       0.039688     0.039758     0.039499     0.040224     0.039958
# min       0.410071     0.410529     0.420748     0.423644     0.433348
# 25%       0.491386     0.493799     0.498881     0.503435     0.509526
# 50%       0.511811     0.513422     0.517609     0.522781     0.529305
# 75%       0.534197     0.536267     0.540212     0.546199     0.553338
# max       0.611510     0.615011     0.618733     0.629111     0.629657
#
#        absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000  ...
# mean      0.535162     0.541422     0.547013     0.555412     0.567684  ...
# std       0.039189     0.039701     0.040120     0.040169     0.040554  ...
# min       0.443661     0.452187     0.453846     0.462065     0.475356  ...
# 25%       0.518136     0.524040     0.530206     0.538221     0.549403  ...
# 50%       0.536688     0.542683     0.549142     0.557966     0.571150  ...
# 75%       0.560895     0.566847     0.571733     0.580239     0.592723  ...
# max       0.635399     0.646464     0.651633     0.659494     0.672586  ...
#
#        absorbance164  absorbance165  absorbance166  absorbance167  \
# count    3660.000000    3660.000000    3660.000000    3660.000000
# mean        1.289545       1.283293       1.279753       1.279127
# std         0.084409       0.092749       0.099267       0.103620
# min         1.072172       1.034615       1.021928       1.006857
# 25%         1.219899       1.210427       1.207287       1.204115
# 50%         1.297526       1.290192       1.285286       1.284157
# 75%         1.360142       1.361769       1.358980       1.362179
# max         1.474019       1.493699       1.514077       1.528783
#
#        absorbance168  absorbance169          id          std  temperature  \
# count    3660.000000    3660.000000  3660.00000  3660.000000  3660.000000
# mean        1.294189       1.281969  1829.50000     0.005084    40.710525
# std         0.109321       0.105555  1056.69532     0.001303     2.432191
# min         1.007855       0.961242     0.00000     0.002700    35.160000
# 25%         1.209457       1.209979   914.75000     0.004200    38.970000
# 50%         1.299752       1.284840  1829.50000     0.004800    40.840000
# 75%         1.378955       1.362140  2744.25000     0.005700    42.332500
# max         1.582476       1.614832  3659.00000     0.008600    47.440000
#
#           humidity
# count  3660.000000
# mean     32.196145
# std       8.270529
# min      16.570000
# 25%      25.980000
# 50%      30.460000
# 75%      38.447500
# max      53.410000
#
# [8 rows x 174 columns]

# %%
train_trimmed.head()
# Out:
#     Reading_ID  absorbance0  absorbance1  absorbance2  absorbance3  \
# 0  ID_3SSHI56C     0.561557     0.568417     0.571877     0.570884
# 1  ID_599OOLZA     0.558420     0.565449     0.569717     0.570999
# 2  ID_MVJGPQ75     0.530362     0.538530     0.543128     0.546287
# 3  ID_CK6RF8YV     0.594354     0.599457     0.604529     0.605267
# 4  ID_82N6QE6I     0.604401     0.611372     0.614571     0.619713
#
#    absorbance4  absorbance5  absorbance6  absorbance7  absorbance8  ...  \
# 0     0.569032     0.567476     0.565662     0.561901     0.559722  ...
# 1     0.569969     0.568405     0.566628     0.564101     0.559951  ...
# 2     0.547001     0.547120     0.546351     0.544254     0.542802  ...
# 3     0.606276     0.604895     0.603716     0.600683     0.598087  ...
# 4     0.619805     0.622708     0.620036     0.618070     0.616470  ...
#
#    absorbance143  absorbance144  absorbance145  absorbance146  absorbance147  \
# 0       1.271104       1.264029       1.250779       1.254856       1.255224
# 1       1.342430       1.339714       1.332805       1.336324       1.342537
# 2       1.332739       1.335550       1.326775       1.336862       1.316860
# 3       1.263479       1.252612       1.254306       1.247635       1.242321
# 4       1.301750       1.288821       1.299768       1.294653       1.294362
#
#    temperature  humidity  hdl_cholesterol_human  hemoglobin(hgb)_human  \
# 0        42.51     34.01                     ok                     ok
# 1        44.52     32.09                     ok                   high
# 2        45.77     24.80                     ok                     ok
# 3        45.84     36.93                    low                     ok
# 4        38.92     23.88                     ok                     ok
#
#    cholesterol_ldl_human
# 0                     ok
# 1                   high
# 2                   high
# 3                   high
# 4                   high
#
# [5 rows x 154 columns]

# %%
train_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13140 entries, 0 to 13139
# Columns: 154 entries, Reading_ID to cholesterol_ldl_human
# dtypes: float64(150), object(4)
# memory usage: 15.4+ MB

# %%
train_trimmed.describe()
# Out:
#         absorbance0   absorbance1   absorbance2   absorbance3   absorbance4  \
# count  13140.000000  13140.000000  13140.000000  13140.000000  13140.000000
# mean       0.590215      0.597083      0.600618      0.602828      0.603434
# std        0.041268      0.041501      0.041560      0.041508      0.041379
# min        0.407299      0.416705      0.420315      0.423078      0.423848
# 25%        0.564319      0.571027      0.574653      0.576596      0.577122
# 50%        0.594201      0.600954      0.604466      0.607168      0.608071
# 75%        0.613614      0.620183      0.623810      0.625986      0.626439
# max        0.732278      0.743683      0.747690      0.749260      0.749274
#
#         absorbance5   absorbance6   absorbance7   absorbance8   absorbance9  \
# count  13140.000000  13140.000000  13140.000000  13140.000000  13140.000000
# mean       0.602075      0.599335      0.596222      0.593066      0.589816
# std        0.041080      0.040716      0.040453      0.040368      0.040127
# min        0.423839      0.422310      0.421942      0.419578      0.416689
# 25%        0.576443      0.574268      0.571647      0.568491      0.565811
# 50%        0.605993      0.602274      0.598185      0.594525      0.590582
# 75%        0.625180      0.622114      0.618871      0.615843      0.612567
# max        0.746646      0.745059      0.743047      0.739153      0.737969
#
#        ...  absorbance140  absorbance141  absorbance142  absorbance143  \
# count  ...   13140.000000   13140.000000   13140.000000   13140.000000
# mean   ...       1.333918       1.327140       1.320583       1.314208
# std    ...       0.060891       0.060457       0.060267       0.059903
# min    ...       1.142088       1.134481       1.133834       1.124536
# 25%    ...       1.297528       1.291124       1.284462       1.277729
# 50%    ...       1.334284       1.327494       1.320617       1.314573
# 75%    ...       1.372971       1.366158       1.359384       1.353154
# max    ...       1.521588       1.507782       1.502026       1.496057
#
#        absorbance144  absorbance145  absorbance146  absorbance147  \
# count   13140.000000   13140.000000   13140.000000   13140.000000
# mean        1.309417       1.305020       1.301597       1.299224
# std         0.059883       0.059731       0.059607       0.059692
# min         1.121238       1.119583       1.117969       1.110535
# 25%         1.273355       1.268584       1.264794       1.262168
# 50%         1.309585       1.305061       1.301706       1.299526
# 75%         1.348107       1.344020       1.340308       1.337843
# max         1.483685       1.480177       1.486023       1.474680
#
#         temperature      humidity
# count  13140.000000  13140.000000
# mean      41.088709     31.534744
# std        2.964205      8.118994
# min       30.480000     16.610000
# 25%       39.030000     25.057500
# 50%       41.090000     30.075000
# 75%       42.870000     36.700000
# max       52.690000     63.070000
#
# [8 rows x 150 columns]

# %%
test_trimmed.head()
# Out:
#     Reading_ID donation_id  absorbance0  absorbance1  absorbance2  \
# 0  ID_KWUAQLRM     ID_2982     0.600692     0.605104     0.608611
# 1  ID_FN8SIVJJ     ID_2982     0.601620     0.605895     0.609568
# 2  ID_CI4TQCHI     ID_2982     0.601226     0.608085     0.611143
# 3  ID_URJMKNU7     ID_2982     0.606784     0.612443     0.615604
# 4  ID_HBJH67IS     ID_2982     0.602236     0.607339     0.611220
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.608169     0.606985     0.606590     0.603814     0.600409  ...
# 1     0.610188     0.608635     0.607716     0.606237     0.601746  ...
# 2     0.611085     0.608700     0.608647     0.605048     0.601668  ...
# 3     0.616249     0.615097     0.614963     0.611250     0.608559  ...
# 4     0.610289     0.609552     0.607212     0.605949     0.603972  ...
#
#    absorbance142  absorbance143  absorbance144  absorbance145  absorbance146  \
# 0       1.249615       1.244618       1.242537       1.238426       1.233983
# 1       1.256831       1.246188       1.236320       1.242136       1.234657
# 2       1.253063       1.247183       1.245595       1.248910       1.239302
# 3       1.257032       1.244043       1.246127       1.238651       1.236244
# 4       1.258131       1.245495       1.242633       1.241607       1.243308
#
#    absorbance147  id     std  temperature  humidity
# 0       1.235212   0  0.0027        37.09     27.22
# 1       1.233898   1  0.0027        37.20     27.17
# 2       1.236558   2  0.0027        37.30     27.07
# 3       1.243770   3  0.0027        37.38     26.98
# 4       1.234993   4  0.0027        37.48     26.89
#
# [5 rows x 154 columns]

# %%
test_trimmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3660 entries, 0 to 3659
# Columns: 154 entries, Reading_ID to humidity
# dtypes: float64(151), int64(1), object(2)
# memory usage: 4.3+ MB

# %%
test_trimmed.describe()
# Out:
#        absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000
# mean      0.593493     0.600429     0.604043     0.606310     0.607045
# std       0.040986     0.041115     0.041184     0.041178     0.040990
# min       0.502319     0.511833     0.514823     0.517375     0.519095
# 25%       0.574226     0.580523     0.583161     0.584758     0.585296
# 50%       0.597674     0.604568     0.608103     0.610013     0.610174
# 75%       0.618982     0.625596     0.629188     0.631299     0.632768
# max       0.697713     0.709430     0.711777     0.714433     0.710277
#
#        absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# count  3660.000000  3660.000000  3660.000000  3660.000000  3660.000000  ...
# mean      0.605908     0.603618     0.600689     0.597767     0.594695  ...
# std       0.040606     0.040069     0.039787     0.039585     0.039236  ...
# min       0.519198     0.517721     0.515886     0.514086     0.511702  ...
# 25%       0.584836     0.583409     0.580374     0.577448     0.574366  ...
# 50%       0.609030     0.606291     0.602908     0.599528     0.596127  ...
# 75%       0.631213     0.628071     0.624470     0.621035     0.617453  ...
# max       0.711160     0.705642     0.703239     0.701144     0.698535  ...
#
#        absorbance142  absorbance143  absorbance144  absorbance145  \
# count    3660.000000    3660.000000    3660.000000    3660.000000
# mean        1.325147       1.318795       1.313999       1.309967
# std         0.065565       0.065048       0.064834       0.064708
# min         1.176856       1.171057       1.162673       1.162296
# 25%         1.267402       1.262370       1.258273       1.254020
# 50%         1.329542       1.323005       1.317591       1.312959
# 75%         1.373495       1.366983       1.361352       1.358295
# max         1.484868       1.482406       1.463370       1.457950
#
#        absorbance146  absorbance147          id          std  temperature  \
# count    3660.000000    3660.000000  3660.00000  3660.000000  3660.000000
# mean        1.306387       1.304600  1829.50000     0.005084    40.710525
# std         0.064523       0.064665  1056.69532     0.001303     2.432191
# min         1.156644       1.152977     0.00000     0.002700    35.160000
# 25%         1.251090       1.249136   914.75000     0.004200    38.970000
# 50%         1.309951       1.308513  1829.50000     0.004800    40.840000
# 75%         1.353600       1.352547  2744.25000     0.005700    42.332500
# max         1.451564       1.454280  3659.00000     0.008600    47.440000
#
#           humidity
# count  3660.000000
# mean     32.196145
# std       8.270529
# min      16.570000
# 25%      25.980000
# 50%      30.460000
# 75%      38.447500
# max      53.410000
#
# [8 rows x 152 columns]

# %% [markdown]
# ## exploratory data analysis

# %%
train.columns
# Out:
# Index(['absorbance0', 'absorbance1', 'absorbance2', 'absorbance3',
#        'absorbance4', 'absorbance5', 'absorbance6', 'absorbance7',
#        'absorbance8', 'absorbance9',
#        ...
#        'absorbance168', 'absorbance169', 'id', 'std', 'temperature',
#        'humidity', 'hdl_cholesterol_human', 'hemoglobin(hgb)_human',
#        'cholesterol_ldl_human', 'donation_id'],
#       dtype='object', length=178)

# %%
test.columns
# Out:
# Index(['Reading_ID', 'donation_id', 'absorbance0', 'absorbance1',
#        'absorbance2', 'absorbance3', 'absorbance4', 'absorbance5',
#        'absorbance6', 'absorbance7',
#        ...
#        'absorbance164', 'absorbance165', 'absorbance166', 'absorbance167',
#        'absorbance168', 'absorbance169', 'id', 'std', 'temperature',
#        'humidity'],
#       dtype='object', length=176)

# %%
sns.countplot(train['hemoglobin(hgb)_human'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='hemoglobin(hgb)_human', ylabel='count'>

# %%
sns.countplot(train['cholesterol_ldl_human'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cholesterol_ldl_human', ylabel='count'>

# %%
sns.histplot(train['hdl_cholesterol_human'])
# Out:
# <AxesSubplot:xlabel='hdl_cholesterol_human', ylabel='Count'>

# %%
train.iloc[:12,1:120]
# Out:
#     absorbance1  absorbance2  absorbance3  absorbance4  absorbance5  \
# 0      0.528200     0.529795     0.537382     0.540265     0.546260
# 1      0.534852     0.541075     0.544269     0.546594     0.555183
# 2      0.532036     0.540413     0.541964     0.549347     0.555902
# 3      0.531880     0.539558     0.542433     0.549097     0.556224
# 4      0.536424     0.538207     0.541504     0.550546     0.555203
# 5      0.530857     0.535106     0.543665     0.547489     0.553947
# 6      0.540493     0.546373     0.550509     0.557649     0.562912
# 7      0.542735     0.545094     0.549500     0.556996     0.563804
# 8      0.539789     0.545403     0.550815     0.557777     0.565607
# 9      0.540788     0.545774     0.552443     0.556335     0.562146
# 10     0.537437     0.536791     0.547677     0.547738     0.555292
# 11     0.541220     0.544116     0.552062     0.555715     0.561403
#
#     absorbance6  absorbance7  absorbance8  absorbance9  absorbance10  ...  \
# 0      0.550882     0.558865     0.571352     0.585775      0.600688  ...
# 1      0.561367     0.567637     0.582427     0.595801      0.608619  ...
# 2      0.561458     0.567824     0.579568     0.593048      0.607972  ...
# 3      0.561398     0.566963     0.577525     0.591982      0.607109  ...
# 4      0.560394     0.567352     0.579438     0.592049      0.606031  ...
# 5      0.560714     0.566400     0.577184     0.593067      0.605521  ...
# 6      0.567507     0.575104     0.584626     0.598158      0.613247  ...
# 7      0.569884     0.576871     0.586514     0.600748      0.613677  ...
# 8      0.571033     0.576663     0.588904     0.601022      0.613541  ...
# 9      0.568546     0.576400     0.587964     0.599927      0.614506  ...
# 10     0.561555     0.570255     0.580264     0.593871      0.606556  ...
# 11     0.566942     0.576630     0.588508     0.598528      0.610697  ...
#
#     absorbance110  absorbance111  absorbance112  absorbance113  absorbance114  \
# 0        1.708177       1.708638       1.700817       1.698755       1.697645
# 1        1.726897       1.738750       1.741579       1.734849       1.729835
# 2        1.745605       1.744391       1.739831       1.740479       1.736988
# 3        1.742863       1.745085       1.749238       1.748590       1.752427
# 4        1.743580       1.744258       1.745526       1.739310       1.734160
# 5        1.740271       1.740094       1.751052       1.739522       1.730801
# 6        1.740271       1.732091       1.742669       1.740293       1.741439
# 7        1.740535       1.750512       1.745445       1.747020       1.746532
# 8        1.744618       1.744018       1.753064       1.740426       1.744774
# 9        1.734611       1.741601       1.744268       1.746211       1.733292
# 10       1.742280       1.741601       1.746840       1.744462       1.742727
# 11       1.744352       1.744204       1.742722       1.742185       1.730801
#
#     absorbance115  absorbance116  absorbance117  absorbance118  absorbance119
# 0        1.698235       1.686467       1.682201       1.677926       1.664489
# 1        1.721689       1.719971       1.711828       1.703872       1.696749
# 2        1.738282       1.723489       1.716638       1.707541       1.708297
# 3        1.734822       1.729688       1.732650       1.713426       1.698000
# 4        1.733737       1.719431       1.710456       1.704452       1.708272
# 5        1.736575       1.727848       1.715687       1.703721       1.702738
# 6        1.737828       1.726199       1.720281       1.710090       1.707093
# 7        1.736762       1.733472       1.720696       1.712294       1.702409
# 8        1.736762       1.727193       1.720696       1.709937       1.707349
# 9        1.738737       1.725102       1.731823       1.715337       1.705050
# 10       1.724968       1.724764       1.719270       1.718661       1.706990
# 11       1.729474       1.722011       1.716844       1.712089       1.703194
#
# [12 rows x 119 columns]

# %%
idx = test.Reading_ID.values
newtest=test.drop(["Reading_ID"],axis=1)
testdata = newtest

# %%
testdata.shape
# Out:
# (3660, 175)

# %%
test.shape
# Out:
# (3660, 176)

# %%
nnewtrain= newtrain.to_numpy()

# %%
features = np.array(nnewtrain[:,:172], dtype=float)
labels = nnewtrain[:, 172:]

# %% [markdown]
# ## Basic Modelling

# %%
labels_n = np.zeros(labels.shape)
labels_n[np.where(labels=='low')] = 0
labels_n[np.where(labels=='ok')] = 1
labels_n[np.where(labels=='high')]= 2

# %%
from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle

# %%
n_samples, n_features = features.shape
n_outputs = labels_n.shape[1]
n_classes = 3
forest = RandomForestClassifier(random_state=32)
multi_target_forest = MultiOutputClassifier(forest, n_jobs=-1)
model = multi_target_forest.fit(features, labels_n)

# %%
multi_target_forest.score(features, labels_n)
# Out:
# 1.0

# %%
def mymultimodel(features):
    output = model.predict(features)
    return output

# %%
multipredictions=mymultimodel(testdata)
ss = pd.DataFrame()
ss["Reading_ID"] = idx
ss["hdl_cholesterol_human"] = multipredictions[:,0]
ss["hemoglobin(hgb)_human"] = multipredictions[:,1]
ss["cholesterol_ldl_human"] = multipredictions[:,2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-ec75a8d6f698> in <module>
# ----> 1 multipredictions=mymultimodel(testdata)
#       2 ss["Reading_ID"] = idx
#       3 ss["hdl_cholesterol_human"] = multipredictions[:,0]
#       4 ss["hemoglobin(hgb)_human"] = multipredictions[:,1]
#       5 ss["cholesterol_ldl_human"] = multipredictions[:,2]
#
# <ipython-input-166-141c61da1f36> in mymultimodel(features)
#       1 def mymultimodel(features):
# ----> 2     output = model.predict(features)
#       3     return output
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\multioutput.py in predict(self, X)
#     203                              " a predict method")
#     204
# --> 205         X = check_array(X, force_all_finite=False, accept_sparse=True)
#     206
#     207         y = Parallel(n_jobs=self.n_jobs)(
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'ID_2982'

# %%
def transform(value):
    if value =='0.0':
        return 'low'
    if value =='1.0':
        return 'ok'
    if value =='2.0':
        return 'high'

# %%
ss["hdl_cholesterol_human"]=ss["hdl_cholesterol_human"].apply(lambda x : transform(x))
ss["hemoglobin(hgb)_human"]=ss["hemoglobin(hgb)_human"].apply(lambda x : transform(x))
ss["cholesterol_ldl_human"]=ss["cholesterol_ldl_human"].apply(lambda x : transform(x))

# %%
ss.head()

# %% [markdown]
# ## Converting my predictions

# %%
def transform_c_hdl(row):
    return str (row["donation_id"]) + str (row["hdl_cholesterol_human"]) + "-" + str (row["hdl_cholesterol_human"])

# %%
hdl_rows = pd.DataFrame(ss.apply(transform_c_hdl, axis=1))

# %%
def transform_hemo(row):
    return str (row["donation_id"]) + str(row["hemoglobin(hgb)_human"]) + "-" + str(row["hemoglobin(hgb)_human"])

# %%
hemo_rows = pd.DataFrame(ss.apply(transform_hemo, axis=1))

# %%
def transform_c_ldl(row):
    return str(row["donation_id"]) + str(row["cholesterol_ldl_human"]) + "-" + str(row["cholesterol_ldl_human"])

# %%
ldl_rows = pd.DataFrame(ss.apply(transform_c_ldl, axis=1))

# %%
ss = pd.concat([hdl_rows, hemo_rows, ldl_rows,]).reset_index(drop=True)

# %%
ss["target"] = ss[0].apply(lambda x: x.split("-")[1])
ss[0] = ss[0].apply(lambda x: x.split("-")[0])

# %%
ss = ss.rename(columns={0:"donation_id"})

# %%
ss.to_csv('My_New_Submission.csv',index=False)
